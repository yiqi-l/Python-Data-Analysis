# %%
import pandas as pd

# %%
df = pd.read_csv('online_retail_cleaned_dataset.csv')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_22492\1083256152.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('online_retail_cleaned_dataset.csv')

# %%
df_clean = df.copy()

# %%
df_clean.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Revenue    Month  \
# 0  2010/12/1 8:26       2.55       17850  United Kingdom    15.30  2010-12
# 1  2010/12/1 8:26       3.39       17850  United Kingdom    20.34  2010-12
# 2  2010/12/1 8:26       2.75       17850  United Kingdom    22.00  2010-12
# 3  2010/12/1 8:26       3.39       17850  United Kingdom    20.34  2010-12
# 4  2010/12/1 8:26       3.39       17850  United Kingdom    20.34  2010-12
#
#    IsNotUK  Unnamed: 11      Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0    False          NaN              NaN          NaN          NaN
# 1    False          NaN  Total Revenue :          NaN  8911407.904
# 2    False          NaN              NaN          NaN          NaN
# 3    False          NaN   Total Orders :          NaN    18536.000
# 4    False          NaN              NaN          NaN          NaN
#
#    Unnamed: 15
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 16 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  int64
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  object
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  int64
#  7   Country      397924 non-null  object
#  8   Revenue      397924 non-null  float64
#  9   Month        397924 non-null  object
#  10  IsNotUK      397924 non-null  bool
#  11  Unnamed: 11  0 non-null       float64
#  12  Unnamed: 12  4 non-null       object
#  13  Unnamed: 13  0 non-null       float64
#  14  Unnamed: 14  3 non-null       float64
#  15  Unnamed: 15  0 non-null       float64
# dtypes: bool(1), float64(6), int64(3), object(6)
# memory usage: 45.9+ MB

# %%
df_clean.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 397919      False      False        False     False        False      False
# 397920      False      False        False     False        False      False
# 397921      False      False        False     False        False      False
# 397922      False      False        False     False        False      False
# 397923      False      False        False     False        False      False
#
#         CustomerID  Country  Revenue  Month  IsNotUK  Unnamed: 11  \
# 0            False    False    False  False    False         True
# 1            False    False    False  False    False         True
# 2            False    False    False  False    False         True
# 3            False    False    False  False    False         True
# 4            False    False    False  False    False         True
# ...            ...      ...      ...    ...      ...          ...
# 397919       False    False    False  False    False         True
# 397920       False    False    False  False    False         True
# 397921       False    False    False  False    False         True
# 397922       False    False    False  False    False         True
# 397923       False    False    False  False    False         True
#
#         Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15
# 0              True         True         True         True
# 1             False         True        False         True
# 2              True         True         True         True
# 3             False         True        False         True
# 4              True         True         True         True
# ...             ...          ...          ...          ...
# 397919         True         True         True         True
# 397920         True         True         True         True
# 397921         True         True         True         True
# 397922         True         True         True         True
# 397923         True         True         True         True
#
# [397924 rows x 16 columns]

# %%
df_clean=df_clean.loc[:,~df_clean.columns.str.contains('Unnamed')]

# %%
df_clean['InvoiceDate'] = pd.to_datetime(df_clean['InvoiceDate'])
df_clean['InvoiceDate']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 397919   2011-12-09 12:50:00
# 397920   2011-12-09 12:50:00
# 397921   2011-12-09 12:50:00
# 397922   2011-12-09 12:50:00
# 397923   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 397924, dtype: datetime64[ns]

# %%
df_clean['CustomerID'] = df_clean['CustomerID'].astype(str)
df_clean['CustomerID']
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
#           ...
# 397919    12680
# 397920    12680
# 397921    12680
# 397922    12680
# 397923    12680
# Name: CustomerID, Length: 397924, dtype: object

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  int64
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  object
#  7   Country      397924 non-null  object
#  8   Revenue      397924 non-null  float64
#  9   Month        397924 non-null  object
#  10  IsNotUK      397924 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 30.7+ MB

# %%
df_clean.describe()
# Out:
#            InvoiceNo       Quantity                    InvoiceDate  \
# count  397924.000000  397924.000000                         397924
# mean   560617.126645      13.021823  2011-07-10 23:43:36.912475648
# min    536365.000000       1.000000            2010-12-01 08:26:00
# 25%    549234.000000       2.000000            2011-04-07 11:12:00
# 50%    561893.000000       6.000000            2011-07-31 14:39:00
# 75%    572090.000000      12.000000            2011-10-20 14:33:00
# max    581587.000000   80995.000000            2011-12-09 12:50:00
# std     13106.167695     180.420210                            NaN
#
#            UnitPrice        Revenue
# count  397924.000000  397924.000000
# mean        3.116174      22.394749
# min         0.000000       0.000000
# 25%         1.250000       4.680000
# 50%         1.950000      11.800000
# 75%         3.750000      19.800000
# max      8142.750000  168469.600000
# std        22.096788     309.055588

# %%
(df['Description']=='').sum()
# Out:
# np.int64(0)

# %%
(df['CustomerID']== 0).sum()
# Out:
# np.int64(0)

# %%
(df_clean['Quantity'] < 0).sum()
# Out:
# np.int64(0)

# %%
(df_clean['UnitPrice'] < 0).sum()
# Out:
# np.int64(0)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  int64
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  object
#  7   Country      397924 non-null  object
#  8   Revenue      397924 non-null  float64
#  9   Month        397924 non-null  object
#  10  IsNotUK      397924 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 30.7+ MB

# %% [markdown]
# ## 探索性分析 ##

# %% [markdown]
# **整体销售概览**
# 总销售额，总订单数，总客户数分别是多少？
# 平均客单价，平均每单购买数量是多少？

# %%
#总销售额   表中 Revenue 已经是单价*数量  可直接求和
total_Revenue = df_clean['Revenue'].sum()
print(total_Revenue)
# Out:
# 8911407.904

# %%
#总订单数  每一条InvoiceNo代表一单，去重计数
total_orders = df_clean['InvoiceNo'].nunique()
print(total_orders)
#nunique()意为 统计某一列中不重复值的个数
# Out:
# 18536

# %%
#总客户数 
total_Customers = df_clean['CustomerID'].nunique()
print(total_Customers)
# Out:
# 4339

# %%
#平均客单价
avg_order_price = total_Revenue / total_orders
print(avg_order_price)
# Out:
# 480.7621873111782

# %%
#平均每单购买数量
total_quantity = df_clean["Quantity"].sum()
avg_quantity_per_order = total_quantity / total_orders
print(total_quantity)
print(avg_quantity_per_order)
# Out:
# 5181696
# 279.5476909797151

# %%
print(f"总销售额:{total_Revenue:,.2f}元")
print(f"总订单数:{total_orders}单")
print(f"总客户数量:{total_Customers}位")
print(f"总销售数量:{total_quantity}件")
print(f"平均客单价:{avg_order_price:,.2f}元")
print(f"平均每单购买数量:{avg_quantity_per_order:,.2f}件")
# Out:
# 总销售额:8,911,407.90元
# 总订单数:18536单
# 总客户数量:4339位
# 总销售数量:5181696件
# 平均客单价:480.76元
# 平均每单购买数量:279.55件

# %% [markdown]
# **时间趋势分析**

# %% [markdown]
# 销售额在一年内如何变化？哪个月最高？哪个月最低？是否存在季节性

# %%
#按月份聚合销售额（Month列已经是字符串如2010-12）
monthly_sales = df_clean.groupby('Month')['Revenue'].sum().reset_index()
print(monthly_sales)
# Out:
#       Month      Revenue
# 0   2010-12   572713.890
# 1   2011-01   569445.040
# 2   2011-02   447137.350
# 3   2011-03   595500.760
# 4   2011-04   469200.361
# 5   2011-05   678594.560
# 6   2011-06   661213.690
# 7   2011-07   600091.011
# 8   2011-08   645343.900
# 9   2011-09   952838.382
# 10  2011-10  1039318.790
# 11  2011-11  1161817.380
# 12  2011-12   518192.790

# %%
#将month列转换为日期类型以便排序
monthly_sales['Month'] = pd.to_datetime(monthly_sales['Month'])
monthly_sales = monthly_sales.sort_values('Month') #sort_values 是排序 括号里面是month 意为按month这一列来排序 默认升序（从小到大）
print(monthly_sales.head(12))
# Out:
#         Month      Revenue
# 0  2010-12-01   572713.890
# 1  2011-01-01   569445.040
# 2  2011-02-01   447137.350
# 3  2011-03-01   595500.760
# 4  2011-04-01   469200.361
# 5  2011-05-01   678594.560
# 6  2011-06-01   661213.690
# 7  2011-07-01   600091.011
# 8  2011-08-01   645343.900
# 9  2011-09-01   952838.382
# 10 2011-10-01  1039318.790
# 11 2011-11-01  1161817.380

# %%
#查看所有月份的数据
print(monthly_sales.to_string(index = False))
# Out:
#      Month     Revenue
# 2010-12-01  572713.890
# 2011-01-01  569445.040
# 2011-02-01  447137.350
# 2011-03-01  595500.760
# 2011-04-01  469200.361
# 2011-05-01  678594.560
# 2011-06-01  661213.690
# 2011-07-01  600091.011
# 2011-08-01  645343.900
# 2011-09-01  952838.382
# 2011-10-01 1039318.790
# 2011-11-01 1161817.380
# 2011-12-01  518192.790

# %% [markdown]
# **折线图**

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (12 , 5))
plt.plot(monthly_sales['Month'],monthly_sales['Revenue'],marker = 'o', linestyle = '-')
plt.title('Monthly Sales Revenue')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation = 45)
plt.grid(True)
plt.tight_layout() #自动调整布局
plt.show()

# %%
monthly_sales['Month'] = pd.to_datetime(monthly_sales['Month'])
monthly_sales.dtypes
# Out:
# Month      datetime64[ns]
# Revenue           float64
# dtype: object

# %%
#销售额最高月份和最低月份
max_month = monthly_sales.loc[monthly_sales['Revenue'].idxmax()]
min_month = monthly_sales.loc[monthly_sales['Revenue'].idxmin()]
print('\n分析结论')
print(f"销售额最高月份:{max_month['Month'].strftime('%Y-%m')},销售额:{max_month['Revenue']:,.2f}元")
print(f"销售额最低月份:{min_month['Month'].strftime('%Y-%m')},销售额:{min_month['Revenue']:,.2f}元")
# Out:
# 分析结论
# 销售额最高月份:2011-11,销售额:1,161,817.38元
# 销售额最低月份:2011-02,销售额:447,137.35元

# %%
df_clean.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue    Month  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30  2010-12
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34  2010-12
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom    22.00  2010-12
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34  2010-12
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34  2010-12
#
#    IsNotUK
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %% [markdown]
# 哪些产品对销售额贡献最大？是否集中在少数产品上？找出销售排名前10的产品，并计算每个产品占总销售额的百分比

# %%
#计算每个产品的销售总额，按降序排列
product_sales = df_clean.groupby('StockCode')['Revenue'].sum().sort_values(ascending = False)
top10_products = product_sales.head(10)
print(top10_products)
# Out:
# StockCode
# 23843     168469.60
# 22423     142592.95
# 85123A    100603.50
# 85099B     85220.78
# 23166      81416.73
# POST       77803.96
# 47566      68844.33
# 84879      56580.34
# M          53779.93
# 23084      51346.20
# Name: Revenue, dtype: float64

# %%
total_products = df_clean['StockCode'].nunique()
print(total_products)
# Out:
# 3665

# %%
#计算前20%的产品数量（至少取1个）
top_n = max(1,int(total_products * 0.2))
top_products = product_sales.head(top_n)
#计算各产品的销售额占比
top_sales_sum = top_products.sum()
total_sales = product_sales.sum()
share = top_sales_sum / total_sales
print(f'前百分之20%的产品(共{top_n}种)贡献的销售额占比:{share:.2%}')
# Out:
# 前百分之20%的产品(共733种)贡献的销售额占比:78.65%

# %% [markdown]
# ## 用户分层 （RFM分析)

# %% [markdown]
# R(Recency):客户最近一次购买日期(越近越好)
# F(Frequency):客户购买次数(越多越好)
# M(Monetary):客户总消费金额(越高越好)

# %% [markdown]
# R(Recency)计算

# %%
#确定参考日期（通常取数据中最大的日期 + 1 天）
ref_date = df_clean['InvoiceDate'].max() + pd.DateOffset(days = 1)
print(f'参考日期：{ref_date}')
# Out:
# 参考日期：2011-12-10 12:50:00

# %%
df_clean.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue    Month  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30  2010-12
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34  2010-12
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom    22.00  2010-12
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34  2010-12
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34  2010-12
#
#    IsNotUK
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %%
#按客户分组，取最近购买日期
recency_raw = df_clean.groupby('CustomerID')['InvoiceDate'].max()

# %%
#计算天数差 (R值)
recency = (ref_date - recency_raw).dt.days
print(recency.head())
# Out:
# CustomerID
# 12346    326
# 12347      2
# 12348     75
# 12349     19
# 12350    310
# Name: InvoiceDate, dtype: int64

# %% [markdown]
# F(Frequency)计算

# %%
#每个客户的购买次数
frequency = df_clean.groupby('CustomerID')['InvoiceNo'].nunique()
print(frequency.head())
# Out:
# CustomerID
# 12346    1
# 12347    7
# 12348    4
# 12349    1
# 12350    1
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# M(Monetary)计算

# %%
#每个客户的总消费金额
monetary = df_clean.groupby('CustomerID')['Revenue'].sum()
print(monetary.head())
# Out:
# CustomerID
# 12346    77183.60
# 12347     4310.00
# 12348     1797.24
# 12349     1757.55
# 12350      334.40
# Name: Revenue, dtype: float64

# %% [markdown]
# 合并RFM

# %%
rfm = pd.DataFrame({'Recency':recency , 'Frequency':frequency , 'Monetary':monetary})
print(rfm.head())
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346           326          1  77183.60
# 12347             2          7   4310.00
# 12348            75          4   1797.24
# 12349            19          1   1757.55
# 12350           310          1    334.40

# %% [markdown]
# RFM评分

# %% [markdown]
# R：天数越小越好，反向打分，最小的天数给最高分 4 分
# F：次数越多越好，正向打分，最大的次数给最高分 4 分
# M：金额越高越好，正向打分，最大的金额给最高分 4 分
# 按四分位数等频分箱（每组大约25%的客户）

# %%
#计算各指标的分位点
r_quantiles = rfm['Recency'].quantile([0.25 , 0.5 , 0.75])
f_quantiles = rfm['Frequency'].quantile([0.25 , 0.5 , 0.75])
m_quantiles = rfm['Monetary'].quantile([0.25 , 0.5 , 0.75])
def score_r(x):
    if x <= r_quantiles[0.25]:
        return 4
    elif x <= r_quantiles[0.5]:
        return 3
    elif x <= r_quantiles[0.75]:
        return 2
    else:
        return 1

def score_f(x):
    if x >= f_quantiles[0.75]:
        return 4
    elif x >= f_quantiles[0.5]:
        return 3
    elif x >= f_quantiles[0.25]:
        return 2
    else:
        return 1

def score_m(x):
    if x >= m_quantiles[0.75]:
        return 4
    elif x >= m_quantiles[0.5]:
        return 3
    elif x >= m_quantiles[0.25]:
        return 2
    else:
        return 1

# %%
rfm['R_score'] = rfm['Recency'].apply(score_r)
rfm['F_score'] = rfm['Frequency'].apply(score_f)
rfm['M_score'] = rfm['Monetary'].apply(score_m)
print(rfm[['Recency', 'R_score' , 'Frequency' , 'F_score' , 'Monetary' , 'M_score']].head())
# Out:
#             Recency  R_score  Frequency  F_score  Monetary  M_score
# CustomerID
# 12346           326        1          1        2  77183.60        4
# 12347             2        4          7        4   4310.00        4
# 12348            75        2          4        3   1797.24        4
# 12349            19        3          1        2   1757.55        4
# 12350           310        1          1        2    334.40        2

# %% [markdown]
# 把三个分数合并为总分或者等级

# %%
#总分(范围3~12)
rfm['Total_Score'] = rfm['R_score'] + rfm['F_score'] + rfm['M_score']

# %%
#按总分划分客户等级
def customer_segment(score):
    if score >= 10:
        return '高价值'
    elif score >= 7:
        return '中价值'
    else:
        return '低价值'

# %%
#定义顺序列表
order = ['高价值' , '中价值' , '低价值']
rfm['Segment'] = rfm['Total_Score'].apply(customer_segment)
print(rfm['Segment'].value_counts().reindex(order))
# Out:
# Segment
# 高价值    1331
# 中价值    1557
# 低价值    1451
# Name: count, dtype: int64

# %%
#查看高价值客户的前10个ID
high_value_customers = rfm[rfm['Segment'] == '高价值']
print(high_value_customers.head(10))
# Out:
#             Recency  Frequency  Monetary  R_score  F_score  M_score  \
# CustomerID
# 12347             2          7   4310.00        4        4        4
# 12352            36          8   2506.04        3        4        4
# 12356            23          3   2811.43        3        3        4
# 12358             2          2   1168.06        4        3        3
# 12362             3         10   5226.23        4        4        4
# 12364             8          4   1313.10        4        3        3
# 12370            51          4   3545.69        3        3        4
# 12371            45          2   1887.96        3        3        4
# 12380            22          4   2724.81        3        3        4
# 12381             5          5   1845.31        4        4        4
#
#             Total_Score Segment
# CustomerID
# 12347                12     高价值
# 12352                11     高价值
# 12356                10     高价值
# 12358                10     高价值
# 12362                12     高价值
# 12364                10     高价值
# 12370                10     高价值
# 12371                10     高价值
# 12380                10     高价值
# 12381                12     高价值
