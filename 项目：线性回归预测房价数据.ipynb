# %% [markdown]
# ## **项目：线性回归预测房价数据**

# %% [markdown]
# ### **分析目标**

# %% [markdown]
# 此数据分析报告的目的是，基于已有的房屋销售价格，以及有关该房屋的属性，进行线性回归分析，从而利用得到的线性回归模型，能对以下未知售价的房屋根据属性进行价格预测：
#
# 面积为6500平方英尺，有4个卧室，2个厕所，总共2层，不位于主路，无客人房，带地下室，有热水器，没有空调，车位数为2，位于城市首选社区，简装修

# %% [markdown]
# ### **简介**

# %% [markdown]
# 数据集house_price.csv记录了超过五百栋房屋的交易价格，以及房屋的相关属性信息，包括房屋面积，卧室数，厕所数，楼层数，是否位于主路，是否有客房，等等
#
# house_price.csv每列含义如下：
# - price: 房屋出售价格
# - area: 房屋面积，以平方英尺为单位
# - bedrooms: 卧室数
# - bathrooms: 厕所数
# - stories: 楼层数
# - mainroad: 是否位于主路
#     - yes: 是
#     - no: 否
# - guestroom: 是否有客房
#     - yes: 是
#     - no: 否
# - basement: 是否有地下室
#     - yes: 是
#     - no: 否
# - hotwaterheating: 是否有热水器
#     - yes: 是
#     - no: 否
# - airconditioning: 是否有空调
#     - yes: 是
#     - no: 否
# - parking: 车库容量，以车辆数量为单位
# - prefarea: 是否位于城市首选社区
#     - yes: 是
#     - no: 否
# - furnishingstatus: 装修状态
#     - furnished: 精装
#     - semi-furnished: 简装
#     - unfurnished: 毛坯

# %% [markdown]
# #### **读取数据**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# 导入数据分析所需要的库，并通过Pandas的read_csv函数，将原始数据文件"house_price_csv"里的数据内容，解析为DataFrame并赋值给变量original_house_price

# %%
original_house_price = pd.read_csv("house_price.csv")
original_house_price.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# #### **评估和清理数据**

# %% [markdown]
# 在这一部分中，我们将对在上一部分建立的original_house_price DataFrame所包含的数据进行评估和清理。
#
# 主要从两个方面进行：结构和内容，即整齐度和干净度。
#
# 数据的结构性问题指不符合"每个变量为一列，每个观察值为有一列，每种类型的观察单位为一个表格"这三个标准；数据的内容性问题包括存在丢失数据、重复数据、无效数据等
#
# 为了区分开经过清理的数据和原始数据，我们创建新的变量cleaned_house_price，让它为original_house_price复制出的副本，我们之后的清理步骤都将被运用在cleaned_house_price上

# %%
cleaned_house_price = original_house_price.copy()

# %% [markdown]
# #### **数据整齐度**

# %%
cleaned_house_price.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# 从头部的10行数据来看，数据符合"每个变量为一列，每个观察值为有一列，每种类型的观察单位为一个表格"，因此不存在结构性问题。

# %% [markdown]
# #### **数据干净度**

# %% [markdown]
# 接下来通过info，对数据内容进行大致了解

# %%
cleaned_house_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# 从输出结果来看，cleaned_house_price共有545条观察值，变量不存在缺失值。
#
# 数据类型方面，我们已知mainroad（是否位于主干道），guestroom（是否有客房），basement（是否有地下室），hotwaterheating （是否有热水器），airconditioning （是否有空调），prefarea （是否位于城市首选社区），furnishingstatus（装修状态），都是分类数据，可以把数据类型都转换为Category

# %%
cleaned_house_price['mainroad'] = cleaned_house_price['mainroad'].astype("category")
cleaned_house_price['guestroom'] = cleaned_house_price['guestroom'].astype("category")
cleaned_house_price['basement'] = cleaned_house_price['basement'].astype("category")
cleaned_house_price['hotwaterheating'] = cleaned_house_price['hotwaterheating'].astype("category")
cleaned_house_price['airconditioning'] = cleaned_house_price['airconditioning'].astype("category")
cleaned_house_price['prefarea'] = cleaned_house_price['prefarea'].astype("category")
cleaned_house_price['furnishingstatus'] = cleaned_house_price['furnishingstatus'].astype("category")

# %%
cleaned_house_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    category
#  6   guestroom         545 non-null    category
#  7   basement          545 non-null    category
#  8   hotwaterheating   545 non-null    category
#  9   airconditioning   545 non-null    category
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    category
#  12  furnishingstatus  545 non-null    category
# dtypes: category(7), int64(6)
# memory usage: 30.3 KB

# %% [markdown]
# #### **处理缺失数据**

# %% [markdown]
# 从info方法输出的结果来看，cleaned_house_price不存在缺失值，因此不需要对缺失数据进行处理

# %% [markdown]
# #### **处理重复数据**

# %% [markdown]
# 根据数据变量的含义以及内容来看，允许变量重复，我们不需要对此数据检查是否存在重复值

# %% [markdown]
# #### **处理不一致数据**

# %% [markdown]
# 不一致数据可能存在于所有分类变量中，我们要查看是否存在不同值实际指代统一目标的情况

# %%
cleaned_house_price["mainroad"].value_counts()
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
cleaned_house_price["guestroom"].value_counts()
# Out:
# guestroom
# no     448
# yes     97
# Name: count, dtype: int64

# %%
cleaned_house_price["basement"].value_counts()
# Out:
# basement
# no     354
# yes    191
# Name: count, dtype: int64

# %%
cleaned_house_price["hotwaterheating"].value_counts()
# Out:
# hotwaterheating
# no     520
# yes     25
# Name: count, dtype: int64

# %%
cleaned_house_price["airconditioning"].value_counts()
# Out:
# airconditioning
# no     373
# yes    172
# Name: count, dtype: int64

# %%
cleaned_house_price["prefarea"].value_counts()
# Out:
# prefarea
# no     417
# yes    128
# Name: count, dtype: int64

# %%
cleaned_house_price["furnishingstatus"].value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %% [markdown]
# 从以上输出结果来看，均不存在不一致数据

# %% [markdown]
# #### **处理无效或错误数据**

# %% [markdown]
# 可以通过DataFrame的describe方法，对数值统计信息进行快速了解

# %%
cleaned_house_price.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# 从以上统计信息来看，cleaned_house_price里不存在脱离现实意义的数值

# %% [markdown]
# #### **探索数据**

# %% [markdown]
# 在着手推断统计学分析之前，我们可以先借助数据可视化，探索数据变量的分布，以及房价存在相关性的变量，为后续的进一步分析提供方向

# %%
# 设置图表色盘为 "pastel"
sns.set_palette("pastel")

# %% [markdown]
# #### **房价分布**

# %%
plt.rcParams["figure.figsize"] = [7.00, 3.50]  #通过 matplotlib 的 rcParams 设置全局参数，指定图表的尺寸为宽度 7 单位、高度 3.5 单位，控制绘图区域大小。
plt.rcParams["figure.autolayout"] = True  #开启 autolayout（自动布局），让Matplotlib自动调整图表元素（标题、坐标轴标签等）的位置，避免重叠，提升排版美观度。
figure, axes = plt.subplots(1, 2) #用 plt.subplots 创建一个包含1行2列子图 的画布（figure）,并返回子图对象数组 axes,后续可在 axes[0]（第一个子图）、axes[1]（第二个子图）分别绘图。
sns.histplot(cleaned_house_price, x='price', ax=axes[0])
sns.boxplot(cleaned_house_price, y='price', ax=axes[1])
plt.show()

# %% [markdown]
# 房价呈右偏态分布，说明数据集中的大多数房子价格中等，但有一些价格很高的极端值，使得均值被拉高

# %% [markdown]
# #### **面积分布**

# %%
figure, axes = plt.subplots(1, 2)
sns.histplot(cleaned_house_price, x='area', ax=axes[0])
sns.boxplot(cleaned_house_price, y='area', ax=axes[1])
plt.show()

# %% [markdown]
# 面积的分布与房价相似，也呈右偏态分布。

# %% [markdown]
# #### **房价与面积的关系**

# %%
sns.scatterplot(cleaned_house_price, x= 'area', y = 'price')
plt.show()

# %% [markdown]
# 从散点图来看，能大致看出一些正相关关系，但关系的强度需要后续通过计算相关性来得到。

# %% [markdown]
# #### **卧室数与房价**

# %%
figure, axes = plt.subplots(1, 2)
sns.histplot(cleaned_house_price, x='bedrooms', ax=axes[0])
sns.barplot(cleaned_house_price, x='bedrooms', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 此数据集中房子的卧室数范围为1-6个，其中大多数房子有2-4个卧室。
#
# 从平均房价与卧室数之间的柱状图来看，当卧室数小于5个时，卧室数多的房子价格也相应高，但一旦多于5个，房价并不一定相应更高

# %% [markdown]
# #### **洗手间数与房价**

# %%
figure, axes = plt.subplots(1, 2)
sns.histplot(cleaned_house_price, x='bathrooms', ax=axes[0])
sns.barplot(cleaned_house_price, x='bathrooms', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 数据集中房子洗手间数量最少一个，最多4个，其中为一个的数量最多
#
# 从平均房价与洗手间数之间的柱状图来看，洗手间多的房子价格也相应高

# %% [markdown]
# #### **楼层数和房价**

# %%
figure, axes = plt.subplots(1, 2)
sns.histplot(cleaned_house_price, x='stories', ax=axes[0])
sns.barplot(cleaned_house_price, x='stories', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 此数据集中房子的楼层数范围为1-4层，其中大多数房子有1层或2层
#
# 从平均房价与楼层数之间的柱状图来看，楼层多的房子价格也相应高

# %% [markdown]
# #### **车库数与房价**

# %%
figure, axes = plt.subplots(1, 2)
sns.histplot(cleaned_house_price, x='parking', ax=axes[0])
sns.barplot(cleaned_house_price, x='parking', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 此数据集中房子的车库数范围为0-3个，不带车库的房子数量是最多的，其次是1个和2个
#
# 从平均房价与楼层数之间的柱状图来看，车库多的房子价格也相应高，但超过2个后，房价并不一定相应高

# %% [markdown]
# #### **是否在主路与房价**

# %%
figure, axes = plt.subplots(1, 2)
mainroad_count = cleaned_house_price['mainroad'].value_counts() #统计 mainroad 字段的类别数量
mainroad_label = mainroad_count.index #获取 mainroad 的类别标签, value_counts() 的结果是带索引的 Series，index 就是 mainroad 的类别标签（如 ['Yes', 'No'] ）
axes[0].pie(mainroad_count, labels=mainroad_label)
sns.barplot(cleaned_house_price, x='mainroad', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 此数据集中房子大多数位于主路
#
# 从平均房价和楼层数之间的柱状图来看，在主路的房子价格也相应高

# %% [markdown]
# #### **是否有客房与房价**

# %%
figure, axes = plt.subplots(1, 2)
guestroom_count = cleaned_house_price['guestroom'].value_counts()
guestroom_label = guestroom_count.index
axes[0].pie(guestroom_count, labels=guestroom_label)
sns.barplot(cleaned_house_price, x='guestroom', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
#  此数据集中房子大部分没有客房，从平均房价与客房的柱状图来看，有客房的房子价格也相应高

# %% [markdown]
# #### **是否有地下室与房价**

# %%
figure, axes = plt.subplots(1, 2)
basement_count = cleaned_house_price['basement'].value_counts()
basement_label = basement_count.index
axes[0].pie(basement_count, labels=basement_label)
sns.barplot(cleaned_house_price, x='basement', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
#   此数据集中房子大部分没有地下室，从平均房价与地下室的柱状图来看，有地下室的房子价格也相应高

# %% [markdown]
# #### **是否有热水器与房价**

# %%
figure, axes = plt.subplots(1, 2)
hotwaterheating_count = cleaned_house_price['hotwaterheating'].value_counts()
hotwaterheating_label = basement_count.index
axes[0].pie(hotwaterheating_count, labels=hotwaterheating_label)
sns.barplot(cleaned_house_price, x='hotwaterheating', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 此数据集中房子大部分没有热水器，从平均房价与热水器的柱状图来看，有热水器的房子价格也相应高

# %% [markdown]
# #### **是否有空调与房价**

# %%
figure, axes = plt.subplots(1, 2)
airconditioning_count = cleaned_house_price['airconditioning'].value_counts()
airconditioning_label = airconditioning_count.index
axes[0].pie(airconditioning_count, labels=airconditioning_label)
sns.barplot(cleaned_house_price, x='airconditioning', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 此数据集中房子大部分没有空调，从平均房价与空调的柱状图来看，有空调的房子价格也相应高

# %% [markdown]
# #### **是否位于城市首选社区与房价**

# %%
figure, axes = plt.subplots(1, 2)
prefarea_count = cleaned_house_price['prefarea'].value_counts()
prefarea_label = prefarea_count.index
axes[0].pie(prefarea_count, labels=prefarea_label)
sns.barplot(cleaned_house_price, x='prefarea', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 此数据集中房子不在城市首选社区，从平均房价与城市首选社区的柱状图来看，在城市首选社区的房子价格也相应高

# %% [markdown]
# #### **装修状态与房价**

# %%
figure, axes = plt.subplots(1, 2)
furnishingstatus_count = cleaned_house_price['furnishingstatus'].value_counts()
furnishingstatus_label = furnishingstatus_count.index
axes[0].pie(furnishingstatus_count, labels=furnishingstatus_label)
sns.barplot(cleaned_house_price, x='furnishingstatus', y = 'price', ax=axes[1])
plt.show()

# %% [markdown]
# 此数据集中简装和毛坯房较多，1/4左右房子为精装
#
# 从平均房价与装修状态的柱状图来看，精装房价格高于简装房子，简装房高于毛坯房

# %% [markdown]
# #### **分析数据**

# %% [markdown]
#  在分析步骤中，我们将利用cleaned_house_price的数据，进行线性回归分析，目标是得到一个可以根据房屋各个属性对价格进行预测的数学模型
#   我们先引入做线性回归所需的模块

# %%
import statsmodels.api as sm

# %% [markdown]
#  然后可以创建一个新的Data Frame 'lr_house_price',让它作为我们进行线性回归分析所用的数据
#
#  和'cleaned_house_price'区分开的原因是，我们在进行线性回归前，还可能需要对数据进行一些准备，比如引入虚拟变量，这些都可以在'lr_house_price'上执行

# %%
lr_house_price = cleaned_house_price.copy()
#lr 是 linear regression 线性回归的简写

# %% [markdown]
#  由于数据里存在分类变量，无法直接建立线性回归模型，我们需要引入虚拟变量，也就是用0和1分别表示是否属于该分类

# %%
lr_house_price = pd.get_dummies(lr_house_price, drop_first=True, columns=['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea', 'furnishingstatus'], dtype=int)
lr_house_price
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0    13300000  7420         4          2        3        2             1
# 1    12250000  8960         4          4        4        3             1
# 2    12250000  9960         3          2        2        2             1
# 3    12215000  7500         4          2        2        3             1
# 4    11410000  7420         4          1        2        2             1
# ..        ...   ...       ...        ...      ...      ...           ...
# 540   1820000  3000         2          1        1        2             1
# 541   1767150  2400         3          1        1        0             0
# 542   1750000  3620         2          1        1        0             1
# 543   1750000  2910         3          1        1        0             0
# 544   1750000  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %% [markdown]
#  接下来，我们把因变量和自变量划分出来
#
#  因变量是price变量，因为我们进行线性回归的目的，是得到一个能根据其他可能对房价有影响的变量，来预测销售价格的模型

# %%
y = lr_house_price['price']

# %% [markdown]
#  我们可以把除价格之外的都纳入自变量，但需要查看它们之间的相关性，如果其中有些变量之间相关性很高，会导致共线性

# %%
x = lr_house_price.drop('price', axis=1)

# %% [markdown]
#  一般我们认为，当相关系数的绝对值大于0.8的时候，可能导致严重共线性，所以我们检查的时候，找绝对值大于0.8的值即可

# %%
x.corr().abs() > 0.8
# Out:
#                                   area  bedrooms  bathrooms  stories  parking  \
# area                              True     False      False    False    False
# bedrooms                         False      True      False    False    False
# bathrooms                        False     False       True    False    False
# stories                          False     False      False     True    False
# parking                          False     False      False    False     True
# mainroad_yes                     False     False      False    False    False
# guestroom_yes                    False     False      False    False    False
# basement_yes                     False     False      False    False    False
# hotwaterheating_yes              False     False      False    False    False
# airconditioning_yes              False     False      False    False    False
# prefarea_yes                     False     False      False    False    False
# ...

# %% [markdown]
#  从以上输出结果来看，不同变量之间相关系数的绝对值均小于0.8

# %% [markdown]
#  接下给模型的线性方程添加截距

# %%
x = sm.add_constant(x) #添加截距
x
# Out:
#      const  area  bedrooms  bathrooms  stories  parking  mainroad_yes  \
# 0      1.0  7420         4          2        3        2             1
# 1      1.0  8960         4          4        4        3             1
# 2      1.0  9960         3          2        2        2             1
# 3      1.0  7500         4          2        2        3             1
# 4      1.0  7420         4          1        2        2             1
# ..     ...   ...       ...        ...      ...      ...           ...
# 540    1.0  3000         2          1        1        2             1
# 541    1.0  2400         3          1        1        0             0
# 542    1.0  3620         2          1        1        0             1
# 543    1.0  2910         3          1        1        0             0
# 544    1.0  3850         3          1        2        0             1
#
#      guestroom_yes  basement_yes  hotwaterheating_yes  airconditioning_yes  \
# ...

# %% [markdown]
# 下一步可以调用OLS函数，利用最小二乘法来得到线性回归模型的参数值

# %%
model = sm.OLS(y, x).fit()  #因变量在前面y，自变量在后面x，调用fit方法进行拟合

# %% [markdown]
#  查看模型结果，使用summary方法获得总结信息

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     87.52
# Date:                Wed, 02 Jul 2025   Prob (F-statistic):          9.07e-123
# Time:                        22:42:15   Log-Likelihood:                -8331.5
# No. Observations:                 545   AIC:                         1.669e+04
# Df Residuals:                     531   BIC:                         1.675e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
#  当我们把显著区间设定为0.05时，以上结果的p值可以看出，模型认为以下因素对房价没有显著性影响：卧室数，是否为简装房。此外，常数（表示线性方程的截距）的p值也很大，说明也没有显著影响
#
#  可以把这些变量移除后，再建立线性回归模型

# %%
x = x.drop(["const", "bedrooms", "furnishingstatus_semi-furnished"], axis=1)

# %%
model = sm.OLS(y, x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.956
# Method:                 Least Squares   F-statistic:                              1088.
# Date:                Wed, 02 Jul 2025   Prob (F-statistic):                        0.00
# Time:                        22:42:15   Log-Likelihood:                         -8333.5
# No. Observations:                 545   AIC:                                  1.669e+04
# Df Residuals:                     534   BIC:                                  1.674e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
#  可以看到，当我们把pz值较大的自变量从线性回归模型中移除后，R方的值从0.682增长到了0.957，提高了模型对现有数据的拟合度

# %% [markdown]
#  根据各个自变量在线性回归方程中的系数来看，模型预测以下因素的增加（或存在）会显著增加房价，：面积，厕所数，楼层数，车库容量，位于主路，有客房，有地下室，有热水器，有空调，位于城市首选社区。
#
#  线性回归模型预测以下因素的增加（或存在）会显著降低房价：未装修，为毛坯房

# %%
#要预测房价的房屋信息：
#面积为6500平方英尺，有4个卧室，2个厕所，总共2层，不位于主路，无客人房，带地下室，有热水器，没有空调，车位数为2，位于城市首选社区，简装修

# %%
price_to_predict = pd.DataFrame({'area': [6500], 'bedrooms': [4], 'bathrooms': [2],
                               'stories': [2], 'mainroad': ['no'], 'guestroom': ['no'],
                               'basement': ['yes'], 'hotwaterheating': ['yes'],
                               'airconditioning': ['no'], 'parking': [2], 'prefarea': ['yes'],
                               'furnishingstatus': ['semi-furnished']})
price_to_predict
# Out:
#    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  6500         4          2        2       no        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0             yes              no        2      yes   semi-furnished

# %% [markdown]
# 我们需要把分类变量的类型转换为Category，并且通过categories参数，让程序知道所有可能的分类值，这样做的原因是，预测数据包含的分类可能不全，我们需要确保引入虚拟变量的时候，不会漏掉某个或某些分类

# %%
price_to_predict['mainroad'] = pd.Categorical(price_to_predict['mainroad'], categories=['no', 'yes'])
price_to_predict['guestroom'] = pd.Categorical(price_to_predict['guestroom'], categories=['no', 'yes'])
price_to_predict['basement'] = pd.Categorical(price_to_predict['basement'], categories=['no', 'yes'])
price_to_predict['hotwaterheating'] = pd.Categorical(price_to_predict['hotwaterheating'], categories=['no', 'yes'])
price_to_predict['airconditioning'] = pd.Categorical(price_to_predict['airconditioning'], categories=['no', 'yes'])
price_to_predict['prefarea'] = pd.Categorical(price_to_predict['prefarea'], categories=['no', 'yes'])
price_to_predict['furnishingstatus'] = pd.Categorical(price_to_predict['furnishingstatus'], categories=['furnished', 'semi-furnished', 'unfurnished'])

# %% [markdown]
#  下一步对分类变量引入虚拟变量

# %%
price_to_predict = pd.get_dummies(price_to_predict, drop_first=True,
                                 columns=['mainroad', 'guestroom',
                                         'basement', 'hotwaterheating',
                                         'airconditioning', 'prefarea',
                                         'furnishingstatus'], dtype=int)
price_to_predict.head()
# Out:
#    area  bedrooms  bathrooms  stories  parking  mainroad_yes  guestroom_yes  \
# 0  6500         4          2        2        2             0              0
#
#    basement_yes  hotwaterheating_yes  airconditioning_yes  prefarea_yes  \
# 0             1                    1                    0             1
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# 0                                1                             0

# %%
price_to_predict = price_to_predict.drop(['bedrooms', 'furnishingstatus_semi-furnished'], axis=1)

# %% [markdown]
#  调用线性回归模型的predict方法，获得预测价格

# %%
predicted_value = model.predict(price_to_predict)
predicted_value
# Out:
# 0    7.303754e+06
# dtype: float64

# %% [markdown]
#  线性回归模型预测的价格为：7303754
